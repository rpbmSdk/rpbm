# %%
import requests
import bs4 as bs
from vsf import *
from pprint import pprint
import os
vsfAgent = VSFAgent()
vsfAgent.auth(os.getenv('VSF_LOGIN'), os.getenv('VSF_PASSWORD'))
articles = vsfAgent.searchEurocodeArticlesClient(eurocode="6574AG")
for article in articles:
    pprint(article.__dict__)

# %%
articles[0].__dict__

# %%
csrf_token = page.find('meta',{'name':'csrf-token'})['content']

# %%
vsfAgent.auth_r.cookies.get_dict()

# %%
div = page.find('div', id = 'articles-list-container')
rawList = div.attrs['data-articles-ids']
articlesIds = json.loads(rawList)
data = {}
for articleId in articlesIds:
    data
r = vsfAgent.session.post(VSF_SEARCH_ARTICLES_URL,params={
    'articlesIds[]': articlesIds
},
headers={
    'x-requested-with':
'XMLHttpRequest',
'X-CSRF-TOKEN': csrf_token
}
)
print(r)

# %%
r.json()

# %%
print(r.json())

# %%
div = page.find('div', id='articles-list-container')
div.attrs['data-articles-ids']

# %%
import json

string_list = '[72587,19425]'
actual_list = json.loads(string_list)
print(actual_list)

# %%
r = vsfAgent.session.get(VSF_SEARCH_URL, params={
        'search': '6539RGSH5RD'
    })
page = bs.BeautifulSoup(r.text, 'html.parser')
catalog = page.find('div', {'id': 'catalog'})
catalog

# %%
catalog

# %%
import requests
session = requests.Session()

# %%
headers = {
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
}
session.headers.update(headers)

# %%
def auth():

    r = session.get(VSF_LOGIN_URL)
    page = bs.BeautifulSoup(r.text, 'html.parser')
    _token = page.find('input', {'name': '_token'})['value']
    r = session.post(VSF_LOGIN_URL, data={
        'login': VSF_LOGIN,
        'password': VSF_PASSWORD,
        '_token': _token,
        'customer_id': None
    })
    # r.raise_for_status()
    return r

r = auth()
r.status_code

# %%
vsfAgent.session.cookies.get_dict()

# %%
session.cookies.get_dict()

# %%
VSF_SEARCH_URL = 'https://client.myvsf.fr/catalogue/vitrage'
def searchEurocode(eurocode:str='6539RGSH5RD'):
    return session.get(VSF_SEARCH_URL, params={
        'search': eurocode
    })

r = searchEurocode()
# print(r.text)
page = bs.BeautifulSoup(r.text, 'html.parser')
catalog = page.find('div', {'id': 'catalog'})
print(catalog)

# %%
print(catalog)

# %%
def articlesClient():
    return session.post('https://client.myvsf.fr/catalogue/articles-client', data={
        'articlesIds[]':72587,
        'articlesIds[]':19425
    }, 
    )

r = articlesClient()

# %%
print(r.text)
